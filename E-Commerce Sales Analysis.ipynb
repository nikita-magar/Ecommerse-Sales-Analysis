# %% [markdown]
# # E-Commerce Sales Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_excel("Sample - Superstore.xls")

# %%
dataset.shape
# Out:
# (9994, 21)

# %%
dataset.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
dataset.isnull().sum() #to find missing values
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# # Prouct Categories

# %%
plt.title("Count of Prouct Categories")
sns.countplot(x="Category",data=dataset)
plt.figure(figsize=(5,3))
plt.savefig("Count of Prouct Categories.jpg")
plt.show()

# %% [markdown]
# # Shiping Mode

# %% [raw]
# # How many products are sales under which shipping mode

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
#To plot graph
x=dataset['Ship Mode'].value_counts().index
y=dataset['Ship Mode'].value_counts().values
plt.pie(y,labels=x,startangle=60,autopct="%0.2f%%")
plt.legend(loc=2)
plt.show()

# %% [markdown]
# #Shipping mode according to product category

# %%
sns.countplot(x="Ship Mode",data=dataset,hue="Category")
plt.show()

# %% [markdown]
# # Cutomer Segment

# %%
sns.countplot(x="Segment",data=dataset)
plt.show()

# %% [markdown]
# # Product Category

# %%
sns.countplot(x="Category",data=dataset,hue="Sub-Category")
#plt.legend(loc=6)
plt.show()

# %%
sns.countplot(x="Category",data=dataset[dataset["Category"]=="Office Supplies"],hue="Sub-Category")
plt.show()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# # To Check number of orders accourding to year

# %%
#to seprate out years from Order date
dataset["Order Year"]=dataset['Order Date'].dt.year

# %%
dataset["Order Year"].value_counts()
# Out:
# Order Year
# 2017    3312
# 2016    2587
# 2015    2102
# 2014    1993
# Name: count, dtype: int64

# %%
sns.countplot(x="Order Year",data=dataset)
plt.show()

# %% [markdown]
# # which catagory contains how much profit

# %%
sns.barplot(x="Category",y="Profit",data=dataset,estimator="sum")
plt.show()

# %% [markdown]
# # Number of Orders according to state

# %%
dataset['State'].value_counts()
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
#to get top 5 states
dataset['State'].value_counts()[:5]
# Out:
# State
# California      2001
# New York        1128
# Texas            985
# Pennsylvania     587
# Washington       506
# Name: count, dtype: int64

# %% [markdown]
# # sales

# %%
sns.barplot(x="Category",y="Sales",data=dataset,estimator=sum)
plt.show()
